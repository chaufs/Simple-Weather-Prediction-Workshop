# %% [markdown]
# <a href="https://colab.research.google.com/github/chaufs/Simple-Weather-Prediction-Workshop/blob/main/SimpleWeatherForecastPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('weather_forecast.csv')
df
# Out:
#      Outlook Temperature Humidity   Windy Play
# 0      Sunny         Hot     High    Weak   No
# 1      Sunny         Hot     High  Strong   No
# 2   Overcast         Hot     High    Weak  Yes
# 3       Rain        Mild     High    Weak  Yes
# 4       Rain        Cool   Normal    Weak  Yes
# 5       Rain        Cool   Normal  Strong   No
# 6   Overcast        Cool   Normal  Strong  Yes
# 7      Sunny        Mild     High    Weak   No
# 8      Sunny        Cool   Normal    Weak  Yes
# 9       Rain        Mild   Normal    Weak  Yes
# 10     Sunny        Mild   Normal  Strong  Yes
# 11  Overcast        Mild     High  Strong  Yes
# 12  Overcast         Hot   Normal    Weak  Yes
# 13      Rain        Mild     High  Strong   No

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#     level_0  index   Outlook Temperature Humidity   Windy Play
# 0         0      0     Sunny         Hot     High    Weak   No
# 1         1      1     Sunny         Hot     High  Strong   No
# 2         2      2  Overcast         Hot     High    Weak  Yes
# 3         3      3      Rain        Mild     High    Weak  Yes
# 4         4      4      Rain        Cool   Normal    Weak  Yes
# 5         5      5      Rain        Cool   Normal  Strong   No
# 6         6      6  Overcast        Cool   Normal  Strong  Yes
# 7         7      7     Sunny        Mild     High    Weak   No
# 8         8      8     Sunny        Cool   Normal    Weak  Yes
# 9         9      9      Rain        Mild   Normal    Weak  Yes
# 10       10     10     Sunny        Mild   Normal  Strong  Yes
# 11       11     11  Overcast        Mild     High  Strong  Yes
# 12       12     12  Overcast         Hot   Normal    Weak  Yes
# 13       13     13      Rain        Mild     High  Strong   No

# %%
df.rename(columns={'level_0':'WeatherID'}, inplace=True)
print(df)
# Out:
#     WeatherID  index   Outlook Temperature Humidity   Windy Play
# 0           0      0     Sunny         Hot     High    Weak   No
# 1           1      1     Sunny         Hot     High  Strong   No
# 2           2      2  Overcast         Hot     High    Weak  Yes
# 3           3      3      Rain        Mild     High    Weak  Yes
# 4           4      4      Rain        Cool   Normal    Weak  Yes
# 5           5      5      Rain        Cool   Normal  Strong   No
# 6           6      6  Overcast        Cool   Normal  Strong  Yes
# 7           7      7     Sunny        Mild     High    Weak   No
# 8           8      8     Sunny        Cool   Normal    Weak  Yes
# 9           9      9      Rain        Mild   Normal    Weak  Yes
# 10         10     10     Sunny        Mild   Normal  Strong  Yes
# 11         11     11  Overcast        Mild     High  Strong  Yes
# 12         12     12  Overcast         Hot   Normal    Weak  Yes
# ...

# %%
df.drop('index', axis=1, inplace=True)
print(df)
# Out:
#     WeatherID   Outlook Temperature Humidity   Windy Play
# 0           0     Sunny         Hot     High    Weak   No
# 1           1     Sunny         Hot     High  Strong   No
# 2           2  Overcast         Hot     High    Weak  Yes
# 3           3      Rain        Mild     High    Weak  Yes
# 4           4      Rain        Cool   Normal    Weak  Yes
# 5           5      Rain        Cool   Normal  Strong   No
# 6           6  Overcast        Cool   Normal  Strong  Yes
# 7           7     Sunny        Mild     High    Weak   No
# 8           8     Sunny        Cool   Normal    Weak  Yes
# 9           9      Rain        Mild   Normal    Weak  Yes
# 10         10     Sunny        Mild   Normal  Strong  Yes
# 11         11  Overcast        Mild     High  Strong  Yes
# 12         12  Overcast         Hot   Normal    Weak  Yes
# 13         13      Rain        Mild     High  Strong   No

# %%
le =  LabelEncoder()
for col in ['Outlook','Temperature', 'Humidity', 'Windy']:
    df[col] = le.fit_transform(df[col])
df
# Out:
#     WeatherID  Outlook  Temperature  Humidity  Windy Play
# 0           0        2            1         0      1   No
# 1           1        2            1         0      0   No
# 2           2        0            1         0      1  Yes
# 3           3        1            2         0      1  Yes
# 4           4        1            0         1      1  Yes
# 5           5        1            0         1      0   No
# 6           6        0            0         1      0  Yes
# 7           7        2            2         0      1   No
# 8           8        2            0         1      1  Yes
# 9           9        1            2         1      1  Yes
# 10         10        2            2         1      0  Yes
# 11         11        0            2         0      0  Yes
# 12         12        0            1         1      1  Yes
# 13         13        1            2         0      0   No

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
x = df.drop(columns=['Play', 'WeatherID' ])
y=df['Play']

# %%
model = RandomForestClassifier(random_state=42)
model.fit(x,y)
y_pred = model.predict(x)

# %%
print ("Accuracy:", accuracy_score(y, y_pred))
print ("Classification Report:\n", classification_report(y, y_pred))
print ("Confusion Matrix:\n", confusion_matrix(y, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#           No       1.00      1.00      1.00         5
#          Yes       1.00      1.00      1.00         9
#
#     accuracy                           1.00        14
#    macro avg       1.00      1.00      1.00        14
# weighted avg       1.00      1.00      1.00        14
#
# Confusion Matrix:
#  [[5 0]
#  [0 9]]

# %%
git init
# Out:
#   File "/tmp/ipython-input-3277417328.py", line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
# !git clone https://github.com/chaufs/Simple-Weather-Prediction-Workshop.git
# Out:
# Cloning into 'Simple-Weather-Prediction-Workshop'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd Simple-Weather-Prediction-Workshop
# Out:
# /content/Simple-Weather-Prediction-Workshop

# %%
   # !git checkout -b main
# Out:
# fatal: A branch named 'main' already exists.
